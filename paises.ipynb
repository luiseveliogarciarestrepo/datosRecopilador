# %%
import pandas as pd
pd.set_option('display.max_rows', 200)
pd.set_option("display.precision", 2)

# %%
df = pd.read_csv('/Users/Dr.LuisEvelioRestrepoGarcia/Desktop/word/tasas_pais_marzo_2020.csv', sep=';')

# %%
df.drop(columns='Tasa de mortalidad por coronavirus', inplace=True)

# %% [markdown]
# ### Fuente:  WHO Marzo 21 de 2020

# %%
df
# Out:
#                                 País  Casos reportados  Fallecidos  \
# 0                              Sudán                 2           1
# 1                              Gabón                 4           1
# 2                             Guyana                 7           1
# 3                            Argelia                94          11
# 4                         San Marino               144          14
# 5                             Italia             47021        4032
# 6                          Indonesia               450          38
# 7                          Guatemala                12           1
# 8                               Irak               208          17
# 9                         Bangladesh                25           2
# 10                              Irán             20610        1556
# 11                           Ucrania                41           3
# 12                          Mauricio                14           1
# ...
